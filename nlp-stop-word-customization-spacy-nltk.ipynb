# %%
import spacy
nlp = spacy.load('en_core_web_sm')

import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(nlp.Defaults.stop_words)

len(nlp.Defaults.stop_words)
# Out:
# {'four', 'toward', '‘m', 'nowhere', 'did', 'eight', 'something', 'them', 'within', 'herself', 'many', 'other', 'cannot', '‘d', '’s', 'move', 'amongst', 'keep', 'our', 'full', 'beforehand', 'should', 'who', 'quite', 'on', 'used', 'become', 'hundred', 'first', 'up', 'he', 'yours', '‘s', 'else', 'noone', 'twelve', 'after', 'do', 'mine', 'against', 'since', 'thence', 'has', 'why', 'few', '’ve', 'wherein', 'though', 'whole', 'still', 'via', 'often', 'nor', 'out', 'third', 'back', 'this', 'latterly', 'whether', 'rather', 'around', 'already', 'themselves', 'onto', 'anyhow', 'see', 'six', 'various', 'wherever', 'because', 'which', 'us', 'yourselves', 'about', 'and', 'make', 'same', 'until', 'however', 'two', 'at', 'well', 'beside', 'off', 'does', 'sometime', 'whereby', "'d", '’ll', 'being', 'ever', 'call', 'everything', 'top', 'made', 'forty', 'seeming', 'yet', 'give', 'then', 'his', 'is', 'anywhere', 'somehow', 'during', 'so', 'yourself', 'former', 'except', 'per', "'ll", 'serious', 'these', 'twenty', 'how', 'from', 'myself', 'her', 'be', 'or', 'almost', 'behind', 'nevertheless', 'of', 'i', 'once', 'thru', 'when', 'moreover', '‘ll', 'another', 'in', 'must', 'thereby', 'below', 'bottom', 'before', 'a', 'over', 'really', 'ourselves', 'very', 'go', 'take', 'mostly', 'fifty', 'side', 'others', '’re', 'whoever', 'therein', 'anything', 'fifteen', 'while', 'your', 'between', 'name', 'five', 'regarding', 'the', 'were', 'are', 'last', 'would', 'together', 'my', 'unless', 'someone', 'never', 'for', "'re", "n't", 'also', '’d', 'into', 'own', 'alone', '‘re', 'as', 'least', 'anyone', 'sixty', 'nine', 'along', 'by', 'done', 'n’t', 'herein', 'ten', 'thereafter', 'too', 'seems', 'every', 'there', 'anyway', 'throughout', 'get', 'three', 'can', 'either', 'across', 'among', 'sometimes', '’m', 'amount', 'hence', 'could', 'part', 'itself', 'besides', 'had', 'nobody', 'it', 'enough', 'hereafter', 'less', 'everyone', 'becoming', 'down', 'put', 'meanwhile', 'without', 'you', 'all', 'any', 'seemed', 'but', 'latter', 'one', 'here', 'under', 'much', 'each', 'whenever', 'always', 'using', 'whither', 'although', 'am', 'no', 'she', 'been', 'upon', 'due', 'was', 'doing', 'several', 'eleven', 'where', 'whose', 'might', 'some', 'hereupon', 'both', 'an', 'whence', 'more', 'whereupon', 'hereby', 'thus', 'everywhere', 're', 'than', 'they', 'we', 'whatever', 'ca', 'their', 'becomes', 'hers', 'whom', 'empty', 'otherwise', 'those', 'somewhere', 'that', 'perhaps', 'whereas', 'just', '‘ve', 'became', 'nothing', 'next', 'neither', 'again', 'will', 'seem', 'whereafter', 'mystery', 'further', 'even', 'afterwards', 'formerly', "'ve", 'with', 'above', 'front', 'n‘t', 'what', 'towards', 'most', 'please', 'indeed', 'may', 'say', 'not', 'have', 'show', 'only', 'thereupon', "'s", 'therefore', 'through', 'to', 'such', 'if', 'its', 'him', 'himself', 'now', "'m", 'ours', 'none', 'me', 'namely', 'elsewhere'}
# 326

# %%
"""## To see if a word is a stop word"""

nlp.vocab['husnain'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('husnain')

# %%
nlp.vocab['husnain'].is_stop = True

len(nlp.Defaults.stop_words)

nlp.vocab['husnain'].is_stop
# Out:
# True

# %%
import string
import re
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
text = 'You have no clue about myself, be care yourself.'


tokens = word_tokenize(text)
print(tokens)
# Out:
# ['You', 'have', 'no', 'clue', 'about', 'myself', ',', 'be', 'care', 'yourself', '.']

# %%
tokens = [w.lower() for w in tokens]
print(tokens)
# Out:
# ['you', 'have', 'no', 'clue', 'about', 'myself', ',', 'be', 'care', 'yourself', '.']

# %%
re_punc = re.compile('[%s]' % re.escape(string.punctuation))
print(re_punc)
# Out:
# re.compile('[!"\\#\\$%\\&\'\\(\\)\\*\\+,\\-\\./:;<=>\\?@\\[\\\\\\]\\^_`\\{\\|\\}\\~]')

# %%
stripped = [re_punc.sub('', w) for w in tokens]
print(stripped)
# Out:
# ['you', 'have', 'no', 'clue', 'about', 'myself', '', 'be', 'care', 'yourself', '']

# %%
words = [word for word in stripped if word.isalpha()]
print(words)
# Out:
# ['you', 'have', 'no', 'clue', 'about', 'myself', 'be', 'care', 'yourself']

# %%
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print(words)

nlp.vocab['clue'].is_stop
# Out:
# ['clue', 'care']
# False
